# %%
import pandas as pd

# %%
kaggle_metadata = pd.read_csv(f'C:/Users/Number One/Desktop/PH_analysis/Movies-ETL/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'C:/Users/Number One/Desktop/PH_analysis/Movies-ETL/ratings.csv')

# %%
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 25063111  260753     1429     4.0   880651146
# 392546      4156     1307     3.5  1118163976
# 24190590  251236     1028     4.5  1086028748
# 1186623    12203     1550     2.0  1112603164
# 6168611    63599     1304     3.5  1483937155

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 20856  False                   NaN      0
# 39679  False                   NaN      0
# 42282  False                   NaN      0
# 4311   False                   NaN      0
# 8001   False                   NaN      0
#
#                                                   genres homepage      id  \
# 20856  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  109669
# 39679  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...      NaN  140423
# 42282  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  394723
# 4311                       [{'id': 18, 'name': 'Drama'}]      NaN    9589
# 8001   [{'id': 878, 'name': 'Science Fiction'}, {'id'...      NaN   42469
#
#          imdb_id original_language  \
# 20856  tt0096243                en
# 39679  tt0068213                he
# 42282  tt5271772                es
# 4311   tt0082176                de
# 8001   tt0068424                en
#
#                                    original_title  \
# 20856                               The Tenth Man
# 39679                         Ani Ohev Otach Rosa
# 42282                                El Hilo Rojo
# 4311   Christiane F. - Wir Kinder vom Bahnhof Zoo
# 8001                           The Creeping Flesh
#
#                                                 overview  ... release_date  \
# 20856  During World War 2 the Germans arrested people...  ...   1988-12-04
# 39679  This story centers on the Jewish practice that...  ...   1972-02-12
# 42282                                                NaN  ...   2016-05-19
# 4311   This movie portrays the drug scene in Berlin i...  ...   1981-04-01
# 8001   A scientist comes to believe that evil is a di...  ...   1973-02-12
#
#       revenue runtime                                   spoken_languages  \
# 20856     0.0   100.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 39679     0.0    77.0          [{'iso_639_1': 'he', 'name': 'עִבְרִית'}]
# 42282     0.0     0.0           [{'iso_639_1': 'es', 'name': 'Español'}]
# 4311      0.0   138.0           [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# 8001      0.0    94.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 20856  Released                                                NaN
# 39679  Released  The unanimous hit of the 1972 Cannes Film Fest...
# 42282   Planned                                                NaN
# 4311   Released                          The image of a generation
# 8001   Released  A terrifying journey through the nightmare wor...
#
#                     title  video vote_average vote_count
# 20856       The Tenth Man  False          5.3        3.0
# 39679     I Love You Rosa  False          6.3        2.0
# 42282        El Hilo Rojo  False          6.6       24.0
# 4311        Christiane F.  False          7.3      268.0
# 8001   The Creeping Flesh  False          6.0       18.0
#
# [5 rows x 24 columns]
